# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_cleann.csv')

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data, columns = ['production_budget_usd'])
y = DataFrame(data, columns = ['worldwide_gross_usd'])

# %%
X.iloc[0:10, :1]
# Out:
#    production_budget_usd
# 0                1000000
# 1                  10000
# 2                 400000
# 3                 750000
# 4                  10000
# 5                1800000
# 6                1000000
# 7                6600000
# 8                1000000
# 9                   7000

# %%
plt.figure(figsize = (12, 6))
plt.scatter(X, y, alpha = 0.3)
plt.title('movie revenue vs production budget')
plt.xlabel('production budget $')
plt.ylabel('worldwide gross $')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
regression = LinearRegression()

# %% [markdown]
# finding the best fit of given data

# %%
regression.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# slope of best fit line:

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %% [markdown]
# slope 3.12 means for every 1usd invested we get 3.12 usd in average which is not bad

# %% [markdown]
# intercept of best fit line:

# %%
regression.intercept_
# Out:
# array([-7236192.72913958])

# %% [markdown]
# intercept -7million means that 1000 usd budget movie are loosing 7 million which doesn't make sense

# %%
regression.score(X, y)
# Out:
# 0.5496485356985729

# %%
plt.figure(figsize = (12, 6))
plt.scatter(X, y, alpha = 0.3)

plt.plot(X, regression.predict(X), color='red', linewidth='4')

plt.title('movie revenue vs production budget')
plt.xlabel('production budget $')
plt.ylabel('worldwide gross $')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()
